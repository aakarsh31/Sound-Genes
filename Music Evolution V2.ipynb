# %% [markdown]
# Imports

# %%
import numpy as np
# This is exclusively used in the test fitness function I have created
# Will be eliminated from the final code

import random as rd
# This is used to initiate the first generation at random positions

from matplotlib import pyplot as plt
# This is used to plot and visualise the code
# Will be eliminated from the final code

import copy
# This is a crucial library used to create true copies of the genes for creating
    # the mutant vector and the trial vector

import time

import wave

# %% [markdown]
# Hyper Parameters

# %%
A=1
# Amplitude
# This is the maximum amplitude or loudness

Cp=0.8
# Crossover Probability
# This is the amount of crossover between the original vector and the mutant
    # vector used to create the trial vector

K=0.8
# Coefficient used to generate the mutant vector

Fr=[1]
# Coefficient used to generate the mutant vector

Ps= 5
# Population Size

Gs= 500
# Generation Size

Cl=100
# Chromosome Length
# This is the number of Time Frames in a single song
# It is set at 3 for the fitness function provided to work

Gl=50
# Gene Length
# This is the number of frequency Bins in a single Time Frame
# It is set at 2 for the fitness function provided to work

fitness=[]
# Best Fitness List
# This is a list of the best fitness in every generation for plotting purposes
# Will be eliminated from the final code

# %% [markdown]
# Test Fitness Function

# %%
T=[]

for i in range(Cl):
    T.append([])
    
    for j in range(Gl):
        T[i].append([rd.uniform(0,A), rd.uniform(0,360)])

# Test Chromosome
# Let us assume that this chromosome is the perfect song
# The goal of our algorithm then is to achieve the closest chromosome that
    # replicates this

# %%
def ff(L):
# Fitness Function
# This must be minimised in the given situation

    E=0
    # Error
    # This will be used to evaluate the fitness of a chromosome

    for j in range(Cl):
        for k in range(Gl):
            for l in range(2):
                E= E + np.abs(L[j][k][l]-T[j][k][l])

    # The error is the manhattan distance of a chromosome from chromosome T
    # Hence the algorithm must minimise this error

    return E

def fitnessFunction(chromosome, index, rasaNumber=1):
    rasas = ['Karuna', 'Shanta', 'Shringar', 'Veera']
    decode(chromosome, f"audio_output/{index}.wav")
    values = dict(computeFitnessValues(rasaNumber=rasaNumber, audioFile=f"{index}.wav"))
    fitnessValue = values["fitnessValues"][rasas[rasaNumber-1]]["weightedSum"]
    return fitnessValue

# %% [markdown]
# Initial Population

# %%
def chrm():
# Random Chromosome Generator
# Creates a random chromosome with the permissible boundary values

    L=[]

    for i in range(Cl):
        L.append([])
        
        for j in range(Gl):
            L[i].append([rd.uniform(0,A), rd.uniform(0,360)])
    
    return L
# decode(chrm(), "3.wav")

# %%
def popinit(Ps):
# Population Initiator
# Creates an initial population pool

# Ps is the Population Size
    
    Pop={}
    # Population Dictionary
    # Pop is a dictionary mapping integers to a unique Chromosome
    # Initiate it as an empty dictionary

    for i in range(Ps):
        Pop[i]=chrm()
    
    # Every element in Pop is a Chromosome indexed from an integer from 0 to Ps

    return Pop

# %% [markdown]
# Vector Generators

# %%
def mutvec(i, Ps, Pop):
# Mutant Vector Generator
# Creates a Mutant Vector for the provided population member

# i is the index of the chromosome whose mutant vector is being created
# Ps is the Population size
# Pop is the Population Dictionary

    Mut=chrm()
    # Mutant Vector
    # Mut is the Mutant Vector of population member index i
    # Initiate it as a random chromosome

    F=rd.uniform(-Fr[0],Fr[0])
    # Coefficient used to generate the mutant vector

    while(1):
        
        x,y,z= rd.sample(range(Ps),3)

        if(x!=i and y!=i and z!=i):
            break
        
    # The above are used to choose population vectors to mutate the original 
        # vector with
    
    for j in range(Cl):
        for k in range(Gl):
            for l in range(2):
                print(f"Pop[x][j][k][l]: {Pop[x][j][k][l]}")
                print(f"Pop[i][j][k][l]: {Pop[i][j][k][l]}")
                print(f"Pop[y][j][k][l]: {Pop[y][j][k][l]}")
                print(f"Pop[z][j][k][l]: {Pop[z][j][k][l]}")
                Mut[j][k][l]= Pop[i][j][k][l]+K*(Pop[x][j][k][l]-Pop[i][j][k][l])+F*(Pop[y][j][k][l]-Pop[z][j][k][l])

                # The above is a direct formula used to create mutant vectors in DE

    # Mut is now the Mutant Vector of population member L

    return Mut

# %%
def trivec(L, Mut):
# Trial Vector Generator
# Creates a Trial Vector for the population member with it's mutant

# L is the chromosome of the population member whose trial vector is being created
# Mut is the population member's corresponding Mutant Vector

    Tri=copy.deepcopy(Mut)
    # Trial Vector
    # Tri is the Trial Vector of the population member L
    # Initiate it to be the Mutant Vector

    for j in range(Cl):
        for k in range(Gl):
            for l in range(2):
                if (rd.uniform(0,1)>Cp):
                    Tri[j][k][l]= L[j][k][l]
                
                # Here as the Tri is the same as Mut initially, elements of Tri
                    # are restored to the value of L with a probability of 1-Cp

    # Tri is now the Trial Vector of the population member L

    return Tri

# %% [markdown]
# Best Fitness Member

# %%
def fittest(Ps, Pop):
# Fittest Population Member Evaluator
# Finds the Population Member with the Greatest Fitness and that Fitness

# Ps is the Population size
# Pop is the Population Dictionary
    
    Bf=10000000
    # Best Fitness
    # This the Best Fitness found
    # Initially it is set to an arbitrarily high number for minimization

    L=Pop[0]
    # This is the chromosome with the highest fitness
    # Initially it is the first chromosome

    for i in range(Ps):
        fitnessValue = fitnessFunction(Pop[i], i, rasaNumber=2)
        if fitnessValue<Bf:
            Bf=fitnessValue
            L=Pop[i]
        
        # Simply keep track of the lowest error among the population members
            
    # Bf is now the best fitness and L is the corresponding population member

    return [L,Bf]

# %% [markdown]
# Generation Iterator/Differential Evolution

# %%
def geniter(Ps, Gs, Pop):
# Generation Iterator
# Iterates over the entire population and creates every generation of members

# Ps is the Population Size
# Gs is the Generation Size
# Pop is the Population Dictionary

    while Gs>0:
        Gs=Gs-1
    # Run the while loop Gs times
    # This imitates Gs Generations of Evolution

        #Fr[0]=Fr[0]/1.01

        for i in range(Ps):
        # For every population member

            Mut= mutvec(i, Ps, Pop)
            # Generate and store the Mutant Vector

            Tri= trivec(Pop[i], Mut)
            # Use the Mutant Vector to create the Trial Vector

            for j in range(Cl):
                for k in range(Gl):

                    if (Tri[j][k][0]>A or Tri[j][k][0]<0):

                        Tri[j][k][0]=Pop[i][j][k][0]
                        
                    if (Tri[j][k][1]>360 or Tri[j][k][1]<0):

                        Tri[j][k][1]=Pop[i][j][k][1]

                    # If a component of the Trial Vector is Violating a constraint, replace
                        # that component with that of the population member
                        
            if(fitnessFunction(Tri, i, rasaNumber=2)<fitnessFunction(Pop[i], i, rasaNumber=2)):
                Pop[i]=Tri

            # If the Trial Vector is fitter than the population member, replace
                # the population member with the trial vector for the next 
                # generation, else do nothing
        
        fitness.append(fittest(Ps, Pop)[1])
        # Append the highest fitness population member of each generation for
            # plotting purposes
        # Will be eliminated from the final code

    return Pop

# %% [markdown]
# Main

# %%
Pop= popinit(Ps)
# Initiate and store the Population Dictionary

Pop= geniter(Ps, Gs, Pop)
# Iterate the population through Evolution and store the final state

print(fittest(Ps, Pop)[1])
# Print the error between the Test chromosome and the Final chromosome

plt.plot(range(0, Gs), fitness)
# Plot the Fitness Vs Generation Curve for Evaluation
# Out:
# Pop[x][j][k][l]: 0.13147161149895337
# Pop[i][j][k][l]: 0.1410973908226073
# Pop[y][j][k][l]: 0.40467543613975054
# Pop[z][j][k][l]: 0.5894609590128413
# Pop[x][j][k][l]: 195.28592236488836
# Pop[i][j][k][l]: 74.88679509372764
# Pop[y][j][k][l]: 97.71573718867576
# Pop[z][j][k][l]: 354.962596315162
# Pop[x][j][k][l]: 0.9365765478550098
# Pop[i][j][k][l]: 0.4514429587880622
# Pop[y][j][k][l]: 0.8711116838299623
# Pop[z][j][k][l]: 0.01411903665179648
# Pop[x][j][k][l]: 182.31561216880345
# Pop[i][j][k][l]: 231.748831632531
# Pop[y][j][k][l]: 308.5332406359499
# Pop[z][j][k][l]: 348.6933166647715
# Pop[x][j][k][l]: 0.4483994922424631
# Pop[i][j][k][l]: 0.7443644854937155
# Pop[y][j][k][l]: 0.22789343617817692
# Pop[z][j][k][l]: 0.8510805404412084
# Pop[x][j][k][l]: 313.19831591485803
# Pop[i][j][k][l]: 79.76028065260478
# Pop[y][j][k][l]: 157.80906041166725
# Pop[z][j][k][l]: 290.9919592334589
# Pop[x][j][k][l]: 0.36415937355012507
# Pop[i][j][k][l]: 0.9504723339251059
# Pop[y][j][k][l]: 0.1032540284768142
# Pop[z][j][k][l]: 0.314357173779962
# Pop[x][j][k][l]: 265.0787733722239
# Pop[i][j][k][l]: 115.42098687925642
# Pop[y][j][k][l]: 51.42589264663929
# Pop[z][j][k][l]: 313.0190529948419
# Pop[x][j][k][l]: 0.4342165829833241
# Pop[i][j][k][l]: 0.3312581747033191
# Pop[y][j][k][l]: 0.6108499280222452
# Pop[z][j][k][l]: 0.11361903577068122
# Pop[x][j][k][l]: 185.95128906997562
# Pop[i][j][k][l]: 252.8280687225913
# Pop[y][j][k][l]: 214.88418126546307
# Pop[z][j][k][l]: 24.12653611570753
# Pop[x][j][k][l]: 0.7243925767753178
# Pop[i][j][k][l]: 0.4045492584743564
# Pop[y][j][k][l]: 0.22707427537104508
# Pop[z][j][k][l]: 0.69941976912496
# Pop[x][j][k][l]: 286.13034106135143
# Pop[i][j][k][l]: 281.13310918664496
# Pop[y][j][k][l]: 10.29400746122581
# Pop[z][j][k][l]: 348.3533477616075
# Pop[x][j][k][l]: 0.709768732586021
# Pop[i][j][k][l]: 0.524931786116502
# Pop[y][j][k][l]: 0.9739555665679299
# Pop[z][j][k][l]: 0.771602964758856
# Pop[x][j][k][l]: 297.19357309207953
# Pop[i][j][k][l]: 355.13812574367444
# Pop[y][j][k][l]: 6.150421689334373
# Pop[z][j][k][l]: 359.47150110978896
# Pop[x][j][k][l]: 0.9719382620539836
# Pop[i][j][k][l]: 0.36996123040227047
# Pop[y][j][k][l]: 0.9990785565375527
# Pop[z][j][k][l]: 0.8305930965198572
# Pop[x][j][k][l]: 90.48785998764629
# Pop[i][j][k][l]: 174.4143410140087
# Pop[y][j][k][l]: 41.84145377293619
# Pop[z][j][k][l]: 341.9629011435486
# Pop[x][j][k][l]: 0.6777767160447647
# Pop[i][j][k][l]: 0.29204297589373496
# Pop[y][j][k][l]: 0.038510246954498784
# Pop[z][j][k][l]: 0.4015719336375255
# Pop[x][j][k][l]: 156.8242559826449
# Pop[i][j][k][l]: 332.1241451237529
# Pop[y][j][k][l]: 267.04931117940663
# Pop[z][j][k][l]: 340.74188937720515
# Pop[x][j][k][l]: 0.8473908555022737
# Pop[i][j][k][l]: 0.6095132477079228
# Pop[y][j][k][l]: 0.5775388891308687
# Pop[z][j][k][l]: 0.27374701590974204
# Pop[x][j][k][l]: 316.47771281164194
# Pop[i][j][k][l]: 26.9857330530834
# Pop[y][j][k][l]: 50.95054370900371
# Pop[z][j][k][l]: 339.9895235564166
# Pop[x][j][k][l]: 0.38227472011267005
# Pop[i][j][k][l]: 0.4702325762780827
# Pop[y][j][k][l]: 0.9680482745710928
# Pop[z][j][k][l]: 0.8290245227996575
# Pop[x][j][k][l]: 182.90481569092154
# Pop[i][j][k][l]: 220.19357404930173
# Pop[y][j][k][l]: 197.11801571216805
# Pop[z][j][k][l]: 320.6358936935368
# Pop[x][j][k][l]: 0.8179354364010764
# Pop[i][j][k][l]: 0.4793293327414224
# Pop[y][j][k][l]: 0.11063401411455254
# Pop[z][j][k][l]: 0.9260828699857262
# Pop[x][j][k][l]: 318.36352405804496
# Pop[i][j][k][l]: 257.7433920830753
# Pop[y][j][k][l]: 347.15619025145156
# Pop[z][j][k][l]: 23.410227034264114
# Pop[x][j][k][l]: 0.1977246952186782
# Pop[i][j][k][l]: 0.008066397245913293
# Pop[y][j][k][l]: 0.8917272714862321
# Pop[z][j][k][l]: 0.6950982855306008
# Pop[x][j][k][l]: 202.78849901818978
# Pop[i][j][k][l]: 358.4183098615454
# Pop[y][j][k][l]: 358.3450351478399
# Pop[z][j][k][l]: 272.76077831433884
# Converting each frame to audio:   0%|          | 0/100 [00:00<?, ?it/s]
# Converting each frame to audio: 100%|██████████| 100/100 [00:09<00:00, 10.77it/s]
# (882000,)
# (100, 50, 20, 3)
# Decoding completed!
# The Decoding Execution Time is: 9.338781595230103 s
# Java command executed successfully
# Current path: e:\RESEARCH\generate-music\Sound-Genes\root
# Data extracted and saved to 0_all_features.json
# The Fitness Function Execution Time is : 1.181969404220581 s
# Results saved to 0_10_features.json
# Converting each frame to audio: 100%|██████████| 100/100 [00:09<00:00, 10.84it/s]
# (882000,)
# (100, 50, 20, 3)
# Decoding completed!
# The Decoding Execution Time is: 9.254125833511353 s
# Java command executed successfully
# Current path: e:\RESEARCH\generate-music\Sound-Genes\root
# Data extracted and saved to 0_all_features.json
# The Fitness Function Execution Time is : 1.0753061771392822 s
# Results saved to 0_10_features.json
# Pop[x][j][k][l]: 0.13147161149895337
# Pop[i][j][k][l]: 0.5894609590128413
# Pop[y][j][k][l]: 0.40467543613975054
# Pop[z][j][k][l]: [0.1410973908226073, 80.29360637228739, 20.0]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# e:\RESEARCH\generate-music\Sound-Genes\root\Music Evolution V2.ipynb Cell 19 line 4
#       <a href='vscode-notebook-cell:/e%3A/RESEARCH/generate-music/Sound-Genes/root/Music%20Evolution%20V2.ipynb#X24sZmlsZQ%3D%3D?line=0'>1</a> Pop= popinit(Ps)
#       <a href='vscode-notebook-cell:/e%3A/RESEARCH/generate-music/Sound-Genes/root/Music%20Evolution%20V2.ipynb#X24sZmlsZQ%3D%3D?line=1'>2</a> # Initiate and store the Population Dictionary
# ----> <a href='vscode-notebook-cell:/e%3A/RESEARCH/generate-music/Sound-Genes/root/Music%20Evolution%20V2.ipynb#X24sZmlsZQ%3D%3D?line=3'>4</a> Pop= geniter(Ps, Gs, Pop)
#       <a href='vscode-notebook-cell:/e%3A/RESEARCH/generate-music/Sound-Genes/root/Music%20Evolution%20V2.ipynb#X24sZmlsZQ%3D%3D?line=4'>5</a> # Iterate the population through Evolution and store the final state
#       <a href='vscode-notebook-cell:/e%3A/RESEARCH/generate-music/Sound-Genes/root/Music%20Evolution%20V2.ipynb#X24sZmlsZQ%3D%3D?line=6'>7</a> print(fittest(Ps, Pop)[1])
#
# e:\RESEARCH\generate-music\Sound-Genes\root\Music Evolution V2.ipynb Cell 19 line 1
#      <a href='vscode-notebook-cell:/e%3A/RESEARCH/generate-music/Sound-Genes/root/Music%20Evolution%20V2.ipynb#X24sZmlsZQ%3D%3D?line=10'>11</a> # Run the while loop Gs times
#      <a href='vscode-notebook-cell:/e%3A/RESEARCH/generate-music/Sound-Genes/root/Music%20Evolution%20V2.ipynb#X24sZmlsZQ%3D%3D?line=11'>12</a> # This imitates Gs Generations of Evolution
#      <a href='vscode-notebook-cell:/e%3A/RESEARCH/generate-music/Sound-Genes/root/Music%20Evolution%20V2.ipynb#X24sZmlsZQ%3D%3D?line=12'>13</a>
#      <a href='vscode-notebook-cell:/e%3A/RESEARCH/generate-music/Sound-Genes/root/Music%20Evolution%20V2.ipynb#X24sZmlsZQ%3D%3D?line=13'>14</a>     #Fr[0]=Fr[0]/1.01
#      <a href='vscode-notebook-cell:/e%3A/RESEARCH/generate-music/Sound-Genes/root/Music%20Evolution%20V2.ipynb#X24sZmlsZQ%3D%3D?line=15'>16</a>     for i in range(Ps):
#      <a href='vscode-notebook-cell:/e%3A/RESEARCH/generate-music/Sound-Genes/root/Music%20Evolution%20V2.ipynb#X24sZmlsZQ%3D%3D?line=16'>17</a>     # For every population member
# ---> <a href='vscode-notebook-cell:/e%3A/RESEARCH/generate-music/Sound-Genes/root/Music%20Evolution%20V2.ipynb#X24sZmlsZQ%3D%3D?line=18'>19</a>         Mut= mutvec(i, Ps, Pop)
#      <a href='vscode-notebook-cell:/e%3A/RESEARCH/generate-music/Sound-Genes/root/Music%20Evolution%20V2.ipynb#X24sZmlsZQ%3D%3D?line=19'>20</a>         # Generate and store the Mutant Vector
#      <a href='vscode-notebook-cell:/e%3A/RESEARCH/generate-music/Sound-Genes/root/Music%20Evolution%20V2.ipynb#X24sZmlsZQ%3D%3D?line=21'>22</a>         Tri= trivec(Pop[i], Mut)
#
# e:\RESEARCH\generate-music\Sound-Genes\root\Music Evolution V2.ipynb Cell 19 line 3
#      <a href='vscode-notebook-cell:/e%3A/RESEARCH/generate-music/Sound-Genes/root/Music%20Evolution%20V2.ipynb#X24sZmlsZQ%3D%3D?line=31'>32</a>             print(f"Pop[y][j][k][l]: {Pop[y][j][k][l]}")
#      <a href='vscode-notebook-cell:/e%3A/RESEARCH/generate-music/Sound-Genes/root/Music%20Evolution%20V2.ipynb#X24sZmlsZQ%3D%3D?line=32'>33</a>             print(f"Pop[z][j][k][l]: {Pop[z][j][k][l]}")
# ---> <a href='vscode-notebook-cell:/e%3A/RESEARCH/generate-music/Sound-Genes/root/Music%20Evolution%20V2.ipynb#X24sZmlsZQ%3D%3D?line=33'>34</a>             Mut[j][k][l]= Pop[i][j][k][l]+K*(Pop[x][j][k][l]-Pop[i][j][k][l])+F*(Pop[y][j][k][l]-Pop[z][j][k][l])
#      <a href='vscode-notebook-cell:/e%3A/RESEARCH/generate-music/Sound-Genes/root/Music%20Evolution%20V2.ipynb#X24sZmlsZQ%3D%3D?line=35'>36</a>             # The above is a direct formula used to create mutant vectors in DE
#      <a href='vscode-notebook-cell:/e%3A/RESEARCH/generate-music/Sound-Genes/root/Music%20Evolution%20V2.ipynb#X24sZmlsZQ%3D%3D?line=36'>37</a>
#      <a href='vscode-notebook-cell:/e%3A/RESEARCH/generate-music/Sound-Genes/root/Music%20Evolution%20V2.ipynb#X24sZmlsZQ%3D%3D?line=37'>38</a> # Mut is now the Mutant Vector of population member L
#      <a href='vscode-notebook-cell:/e%3A/RESEARCH/generate-music/Sound-Genes/root/Music%20Evolution%20V2.ipynb#X24sZmlsZQ%3D%3D?line=39'>40</a> return Mut
#
# TypeError: unsupported operand type(s) for -: 'float' and 'list'

# %%
L=fittest(Ps,Pop)[0]

Jk=chrm()

for j in range(Cl):
        for k in range(Gl):
            for l in range(2):
                Jk[j][k][l]= np.abs(L[j][k][l]-T[j][k][l])

Jk

# %% [markdown]
# Test cases:
#
# Ps,Gs,Cl,Gl -> E,Time
#
# K=0.7
# F=(-2,2)
#
# a) 100,100,3,2 -> 1.7, 1.5
#
# b) 100,100,30,20 -> 46000, 1:20
#
# c) 20,100,30,20 -> 49000, 17
#
# d) 20,200,30,20 -> 44000, 31
#
# e) 20,500,30,20 -> 38000, 1:15
#
# f) 40,200,30,20 -> 42000, 1:03
#
# g) 10,200,30,20 -> 49000, 16
#
# h) 10,1000,30,20 -> 42000, 1:11
#
# i) 20,1000,30,20 -> 34000, 2:29
#
#
# j) 10,10,300,50 -> 1555K, 23
#
# k) 20,10,300,50 -> 1472K, 48
#
# k) 20,50,300,50 -> 1441K, 4:00
#
# l) 30,10,300,50 -> 1511K, 1:12
#
# K=0.8
# F=(-1,1)
#
# a) 10,10,300,50 -> 1522K, 38
#
# b) 20,50,300,50 -> 1476K, 5:41
